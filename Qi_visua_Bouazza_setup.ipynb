# %%
res, res_ES = boxplot_compa_func(trail = 20, alpha_l = [0.85, 0.9, 0.95, 0.975], dim_X = 5, lower = 0.7, upper = 0.99,
                                 hunit_NN = 20, hunit_Qi = 30)
# Out:
# ...
# Empirical probability of true label being lower than true VaR (alpha) =  [0.84942626953125, 0.899200439453125, 0.950531005859375, 0.9766387939453125]
# ====== One hidden layer net ======
# NRMSE in-sample VaR =  [0.1355430781841278, 0.14996229112148285, 0.167207270860672, 0.24309031665325165]
# NRMSE out-sample VaR =  [0.1338789314031601, 0.14834323525428772, 0.1660597324371338, 0.24082745611667633]
# ====== Randomized net ======
# NRMSE in-sample VaR =  [0.42441123723983765, 0.46680644154548645, 0.5238031148910522, 0.6207100749015808]
# NRMSE out-sample VaR =  [0.424225777387619, 0.4654065668582916, 0.5204514265060425, 0.6146107912063599]
# ====== Two hidden layer net ======
# NRMSE in-sample VaR =  [0.1477520763874054, 0.14453929662704468, 0.13702303171157837, 0.20060516893863678]
# NRMSE out-sample VaR =  [0.1450740247964859, 0.14297764003276825, 0.13582675158977509, 0.19676490128040314]
# ====== Multi output net ======
# ...

# %%
res_h, res_ES_h = boxplot_compa_func(trail = 20, alpha_l= [0.85, 0.9, 0.95, 0.975], dim_X = 40, lower = 0.7, upper = 0.99, hunit_Qi = 10)
# Out:
# ...
# Empirical probability of true label being lower than true VaR (alpha) =  [0.850555419921875, 0.9000701904296875, 0.9500885009765625, 0.9756317138671875]
# ====== One hidden layer net ======
# NRMSE in-sample VaR =  [0.5727487802505493, 0.6455537676811218, 0.7656428813934326, 0.8603254556655884]
# NRMSE out-sample VaR =  [0.6038184762001038, 0.6744771003723145, 0.7969945073127747, 0.8891712427139282]
# ====== Randomized net ======
# NRMSE in-sample VaR =  [0.9078428149223328, 0.9146384000778198, 1.0776352882385254, 1.1198850870132446]
# NRMSE out-sample VaR =  [0.9182233214378357, 0.9211894869804382, 1.0892384052276611, 1.1311324834823608]
# ====== Two hidden layer net ======
# NRMSE in-sample VaR =  [0.5920201539993286, 0.6863118410110474, 0.7383875250816345, 0.8442105650901794]
# NRMSE out-sample VaR =  [0.6224159002304077, 0.7250338792800903, 0.7732353806495667, 0.8706133961677551]
# ====== Multi output net ======
# ...
